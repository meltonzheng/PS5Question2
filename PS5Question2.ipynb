# %%
import numpy as np
u = [1,+\
5 ,+\
11,+\
23 ,+\
56 ,+\
183 ,+\
555 ,+\
1351 ,+\
3794 ,+\
7993 ,+\
52001]
a = np.arange(0,11)

# %%
n = []
for _i,_a in enumerate(a):
    n.append(np.log(u[_i])/np.exp(_a))

# %%
n
# Out:
# [0.0,
#  0.5920791198263896,
#  0.32451983591590217,
#  0.15610706489550652,
#  0.0737268879676606,
#  0.03510124159031515,
#  0.01566315596623429,
#  0.006573392645076097,
#  0.0027646066084525455,
#  0.0011090001680773556,
#  0.0004929986648474567]

# %%
errors = [0,0,1,1,2,18,38,71,319,852,4378]

# %%
np.log(errors)
# Out:
# <ipython-input-19-3be11b5ad4ab>:1: RuntimeWarning: divide by zero encountered in log
#   np.log(errors)
# array([      -inf,       -inf, 0.        , 0.        , 0.69314718,
#        2.89037176, 3.63758616, 4.26267988, 5.7651911 , 6.74758653,
#        8.38434728])

# %%
r = [1639,929,602,417,266,152,88.1,61.5,44.4,31.7,13.3]
l = [18.11,2.64,1.74,1.33,1.24,0.72,0.40,0.27,0.20,0.15,0.05]
from matplotlib import pyplot

# %%
pyplot.plot(a,np.log(r))

# %%
pyplot.plot(a,u)

# %%
pyplot.plot(a,np.log(l))

# %%
np.average(beta)
# Out:
# 0.6249976111714554

# %%
np.power(np.average(n),-0.5)
# Out:
# 3.017436888604049

# %%
pyplot.plot(a,np.log(n))
# Out:
# <ipython-input-48-0f3c713b2ee1>:1: RuntimeWarning: divide by zero encountered in log
#   pyplot.plot(a,np.log(n))

# %%
new_n = np.log(n)
new_n_v = []
for _i, _r in enumerate(new_n):
    if(_i < len(r)-1):
        new_n_v.append(r[_i+1]-_r)
# Out:
# <ipython-input-51-d8616ee65c28>:1: RuntimeWarning: divide by zero encountered in log
#   new_n = np.log(n)

# %%
new_n
# Out:
# array([       -inf, -0.524115  , -1.12540862, -1.85721319, -2.60738772,
#        -3.34951878, -4.15644408, -5.0247252 , -5.89085693, -6.80429642,
#        -7.61500409])

# %%
m, b = np.polyfit(np.array(a[1:]), np.array(new_n[1:]), 1)

# %%
pyplot.plot(a, new_n, 'o')
pyplot.plot(np.array(a), m*np.array(a) + b)

# %%
m
# Out:
# -0.7987719564828709

# %%
test_u = np.exp(u)
# Out:
# <ipython-input-82-053c44b3baef>:1: RuntimeWarning: overflow encountered in exp
#   test_u = np.exp(u)

# %%
test_n = []
for _i,_a in enumerate(a):
    test_n.append(np.log(test_u[_i])/np.exp(_a))

# %%
pyplot.plot(a,test_n)

# %%
pyplot.plot(a,np.exp(np.power(u,1/a)))
# Out:
# <ipython-input-84-aa2f3ff6fc98>:1: RuntimeWarning: divide by zero encountered in true_divide
#   pyplot.plot(a,np.exp(np.power(u,1/a)))

# %%
ans = np.exp(np.power(u,1/a))
ans
# Out:
# <ipython-input-87-7b867d1ec4f8>:1: RuntimeWarning: divide by zero encountered in true_divide
#   ans = np.exp(np.power(u,1/a))
# array([  2.71828183, 148.4131591 ,  27.56714845,  17.18207999,
#         15.41844931,  17.02341563,  17.57890239,  16.45296679,
#         16.46896457,  15.09183112,  19.33873178])

# %%
average_branching_ratio = np.average(ans[2:])

# %%
np.power(np.log(average_branching_ratio),-0.5)
# Out:
# 0.5881205725976737

# %%
np.power(np.log(average_branching_ratio),-0.33333)
# Out:
# 0.7019601387643

# %%
beta = []
for _i, _r in enumerate(r):
    if(_i < len(r)-1):
        beta.append(r[_i+1]/_r)

# %%
np.average(beta)
# Out:
# 0.6249976111714554

# %%
gamma = []
for _i, _l in enumerate(l):
    if(_i < len(l)-1):
        gamma.append(l[_i+1]/_l)

# %%
np.average(gamma)
# Out:
# 0.613684015763763

# %%
r_error = [83,97,57,40,30,25,11,4.6,4.9,4.9,2.8]

# %%
pyplot.plot(a,np.log(u))
pyplot.plot(a,m*a+b)

# %%
m, b = np.polyfit(np.array(a), np.array(np.log(u)), 1)

# %%
m
# Out:
# 1.0161117867424567

# %%
np.power(m,-0.5)
# Out:
# 0.9920401639018619

# %%
np.power(m,-0.33333333)
# Out:
# 0.9946863777450762

# %%
m_r, b_r = np.polyfit(np.array(a), np.array(np.log(r)), 1)
m_l, b_l = np.polyfit(np.array(a), np.array(np.log(l)), 1)

# %%
pyplot.plot(a,np.log(r))
pyplot.plot(a,m_r*a+b_r)

# %%
pyplot.plot(a,np.log(l))
pyplot.plot(a,m_l*a+b_l)

# %%
np.power(m_r,-2), np.power(m_l,-3)
# Out:
# (4.775651175021922, -9.607798669935782)
